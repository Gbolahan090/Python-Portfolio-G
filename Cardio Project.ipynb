# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# The code above is used to import necessary libraries needed for the project. They would aid our data cleaning and visualization process. Hence, it is most suitable to be imported before any work is done concerning the project.

# %% [markdown]
# # Importing our Data

# %%
path = r"C:\Users\GBOLAHAN\Desktop\AileadTech Python class\CardioGoodFitness-1.csv"
df = pd.read_csv(path)

# %% [markdown]
# The code above is used to read our Dataset into Jupyter notebook for further process. The Dataset now has a variable name known as df. So we can refer to our Data by just calling the df in our jupyter notebook.

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# The variable name df which refers to the Dataset name as seen above provides an overview of the Dataset. It shows the total observation and features in the Data sets. We have 180 observations and 9 feautures in this Dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# The code above df.info() gives a first hand information of the Dataset in their respective Data Structure format including other details as well as the features containing blanks.

# %%
df.shape
# Out:
# (180, 9)

# %% [markdown]
# The code above df.shape talks about the shape of the Dataset with its respective rows and columns.As mentioned earlier, we have 180 observations aand 9 features in our Dataset.

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %% [markdown]
# The code above df.dtypes provides the Data Structure format of the Dataset whether it is  string or float where object shows that they are strings and are categorical Data wile int64 shows that they integers.

# %%
df.describe(include="all").T
# Out:
#                count unique        top freq          mean           std  \
# Product          180      3      TM195   80           NaN           NaN
# Age            180.0    NaN        NaN  NaN     28.788889      6.943498
# Gender           180      2       Male  104           NaN           NaN
# Education      180.0    NaN        NaN  NaN     15.572222      1.617055
# MaritalStatus    180      2  Partnered  107           NaN           NaN
# Usage          180.0    NaN        NaN  NaN      3.455556      1.084797
# Fitness        180.0    NaN        NaN  NaN      3.311111      0.958869
# Income         180.0    NaN        NaN  NaN  53719.577778  16506.684226
# Miles          180.0    NaN        NaN  NaN    103.194444     51.863605
#
#                    min       25%      50%      75%       max
# Product            NaN       NaN      NaN      NaN       NaN
# Age               18.0      24.0     26.0     33.0      50.0
# Gender             NaN       NaN      NaN      NaN       NaN
# ...

# %% [markdown]
# The code above df.describe(include="all").T describes the numerical Data as regarding their mean std, min. 25%, 50%, 75% and max values.

# %%
df.corr()
# Out:
# C:\Users\GBOLAHAN\AppData\Local\Temp\ipykernel_14160\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %% [markdown]
# The code above shows the correlation between two numerical features. This tells us if there is any relationship between these features in our Dataset. The relatonship could be positive(closer to 1 or 1) or negative(closer to -1 0r -1) or independent(showing no relationship (0)).

# %% [markdown]
# # Checking for Missing Values

# %%
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# The code above df.isna().sum() helps to check for missing values in our Dataset by summing all the blanks and Na's in the respective features we have. As we can see above, there are no missing values in our Dataset.

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# The code above df.head() gives an overview of the the first 5 Dataset from the top if the numbers to display are not stated. This helps to understand the Dataset very well and check for abnomalies.

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# The code above df.tail() gives an overview of the the last 5 Dataset if the numbers to display are not stated. This helps to understand the Dataset very well and check for abnomalies.

# %%
df.sample(n=10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 100   TM498   25  Female         14     Partnered      5        3   47754
# 87    TM498   23    Male         14     Partnered      3        3   36384
# 162   TM798   28  Female         18     Partnered      6        5   92131
# 126   TM498   34    Male         16     Partnered      3        4   59124
# 119   TM498   32    Male         16     Partnered      3        3   53439
# 58    TM195   32    Male         14     Partnered      4        3   52302
# 4     TM195   20    Male         13     Partnered      4        2   35247
# 33    TM195   25    Male         16        Single      3        3   43206
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 44    TM195   28  Female         14     Partnered      2        3   46617
#
#      Miles
# 100    106
# 87      95
# 162    180
# 126     85
# 119     95
# 58      85
# 4       47
# 33      85
# 170    260
# 44      56

# %% [markdown]
# The code above df.sample() provides a sampling overview of the the Dataset if the numbers to display are not stated. This helps to understand the Dataset very well and check for abnomalies.

# %% [markdown]
# # Univariate Data Analysis

# %% [markdown]
# Our Univariate Data Analysis will provide the distribution of our individual features in our Dataset. This brings about initial understanding of our Dataset.

# %%
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %% [markdown]
# The code above df.nunique provides the counts of the unique values or characters in the individual features.

# %%
def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
#     The code above defines the function for our graphs that helps to return percentage on our countplot graphs.

# %% [markdown]
# # Graph showing Product Visualization

# %%
labeled_barplot(df, "Product", perc=True);

# %%
df.Product.value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %% [markdown]
# The Product graph above shows the 3 respective products given their percentage. As observed, Product (TM195) has the highest percentage with about (44.4%) while Product (TM798) has the lowest percentage with about (22.2%). This tells us more that Product (TM195) as the widely used product by customers.

# %% [markdown]
# # Graph showing Age Visualization

# %%
sns.histplot(x="Age", data=df, kde=True);

# %%
df.Age.mean()
# Out:
# 28.788888888888888

# %%
df.Age.median()
# Out:
# 26.0

# %%
df.Age.mode()
# Out:
# 0    25
# Name: Age, dtype: int64

# %% [markdown]
# The Age graph above explains the age distribution of customers. As seen, the most prevalent Age range of customers fall within Age 23 to Age 26 with Age 25 having the highest number of users for the products. Observation made it clearer by showing that people of younger age tends to use the product the more. The younger age range falls within the range of 19 to 30. The graph is rightly skewed. The mean age is 28, median is 26 and mode is 25.

# %% [markdown]
# # Graph showing Gender Visualization

# %%
labeled_barplot(df, "Gender", perc=True);

# %%
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %% [markdown]
# The Gender graph above explains the product distribution of customers based on Gender. It shows both gender actively use the product. It clearly explains that the Male gender with about 57.8% use the product more than the female gender.

# %% [markdown]
# # Graph showing Education Visualization

# %%
labeled_barplot(df, "Education", perc=True, n=None);

# %%
df.Education.value_counts()
# please comment
# Out:
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %% [markdown]
# The Education graph above explains the product distribution of customers based on their Education. Educations explains the numer of years the customers have been aware about the product. As observed from the graph, the educated people with 16 years of knowledge tends to be the one that use the product the most. In line, people with 14 years also tends to use the products well while the educated people within 20 and 21 tend to be less educated about the product. It provides us with an overview that the customers that have known the products for a very long time offset the numbers of customers using the products around that Education range.

# %% [markdown]
# # Graph showing MaritalStatus Visualization

# %%
labeled_barplot(df, "MaritalStatus", perc=True);

# %%
df.MaritalStatus.value_counts()
# We have more of married people using the product.
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# The MaritalStatus graph above explains the product distribution of customers based on their MaritalStatus. It shows both single and partnered customers actively use the product. It clearly explains that the Partnered with about 59.4% use the product more than the single who take only about 40.6%. As seen, we have more of partnered people using the product.

# %% [markdown]
# # Graph showing Usage Visualization

# %%
labeled_barplot(df, "Usage", perc=True);

# %%
df.Usage.value_counts()
# Out:
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: Usage, dtype: int64

# %% [markdown]
# The Usage graph above explains the distribution of customers based on their Usage. Usage explains the average number of times per week the customers use the products. As observed from the graph, customers use the product 3 times per week to 4 times on an average while the least number of days customers use the product is 6 times per week to 7 times. We can depict that customers don't really use the products 5 to 7 times per week.

# %% [markdown]
# # Graph showing Fitness Visualization

# %%
labeled_barplot(df, "Fitness", perc=True);

# %%
df.Fitness.value_counts()
# Out:
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64

# %% [markdown]
# The Fitness graph above explains the distribution of customers based on their fitness. Fitness explains the self rated score input by customers as regarding how fit they are using the product.
# The fitness score 5 and 4 shows that the customers are very fit and closely fit while the score 1 and 2 shows that they are very unfit and closely unfit. As observed from the graph, customers tends to rate themselves score 3 the most which shows that they are fit with total number of about 53.9%. Also, quite an average number of customers rated themselves as very fit and closely fit with a score of 4 and 5.
# It can be seen also that customers who rated themselves 1 as very unfit tends to be the lowest with total customers around 2. We can say from this observation that customers of this product are predominantly fit.

# %% [markdown]
# # Graph showing Income Visualization

# %%
sns.boxplot(x="Income", data=df);

# %%
df.Income.sum()
# Out:
# 9669524

# %%
df.Income.mean()
# Out:
# 53719.57777777778

# %%
df.Income.median()
# Out:
# 50596.5

# %%
df.Income.mode()
# Out:
# 0    45480
# Name: Income, dtype: int64

# %% [markdown]
# The Income graph above explains the distribution of customers based on their income. As observed from the graph, 25% of the customers income ranges from 30,000 to 45,000. 50 percentile of the customers earn between 43,000 to 50,000. 75 percentile of the customers earn between 50,000 to 60,000. There seems to be outliers within the range of incme 80,000 above. The bulk of customners earn within 43,000 to 60,000.

# %%
df.Income.min()
# Out:
# 29562

# %% [markdown]
# # Graph showing Miles Visualization

# %%
sns.histplot(x="Miles", data=df, kde=True );

# %%
df.Miles.sum()
# Out:
# 18575

# %%
df.Miles.mean()
# Out:
# 103.19444444444444

# %%
df.Miles.median()
# Out:
# 94.0

# %%
df.Miles.mode()
# Out:
# 0    85
# Name: Miles, dtype: int64

# %% [markdown]
# The Miles graph above explains the distribution of customers based on the miles covered. As observed from the graph, the mile graph is rightly skewed. The bulk of the customers covered miles within the range of 50 miles to 120 miles. Larger percentage of the customers covered shorter miles.

# %% [markdown]
# # Bivarate Analysis

# %%
Cor=df.corr()

sns.heatmap(data=Cor, vmin=-1, vmax=1, annot=True, cmap="inferno");
plt.figure(figsize=(10,10))
# Out:
# C:\Users\GBOLAHAN\AppData\Local\Temp\ipykernel_14160\4275148053.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Cor=df.corr()

# %% [markdown]
# The graph above explains the correlation between two features in our Datasets. As seen, features with positive relationships occurs within (Age and Income) which is averagely positively related. (Education and Fitness) which is fairly positively related. (Education and Usage) which is fairly positively related. (Education and Income) which is averagely positively related. (Usage and Fitness) which is positively related as well as (Usage and Income). (Usage and Miles) seems to have a strong postitive relationship. (Fitness and Income) tends to be averagely positively related while (Fitness and Miles) are strongly positivey related. (Income and Miles) also tends to be averagely positively related. Fitness and miles shows the most correlation. It means that it is positively related, the more miles the customers run, the more fit they are.

# %%
sns.scatterplot(data=df, x="Income", y="Age");

# %% [markdown]
# The graph above shows a scatterplot graph of Income and Age. It shows the distribution of Income of customers with their Age.  This explicitly explains the relationship between Income and Age where the higher the Age, the higher the Income the customer earns.

# %%
sns.scatterplot(data=df, x="Income", y="Miles");

# %% [markdown]
# The graph above shows a scatterplot graph of Income and Miles. It shows the distribution of Income of customers with the Miles covered. This explicitly explains the relationship between Income and Miles where the higher the Income, the higher the Miles covered.

# %%
sns.lineplot(data=df, x="Fitness", y="Miles");

# %% [markdown]
# The graph above shows a categorical plot graph of Fitness and Miles. It shows the distribution of Miles covered of customers with their Fitness. This explicitly explains the relationship between Miles and Fitness where the higher the number of Miles covered, the higher their fitness rating. Though with few outliers.

# %%
sns.lineplot(data=df, x="Fitness", y="Usage");

# %% [markdown]
# The graph above shows a categorical plot graph of Fitness and Usage. It shows the distribution of usage of the product by customers with their Fitness. This explicitly explains the relationship between Usage and Miles where the higher the number of usage, the higher their fitness rating.

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box");

# %% [markdown]
# The graph above shows a categorical plot graph of Income and Product. It shows the distribution of income for customers with their product. This explicitly explains the relationship where for product TM195, the customers earn around 38,000 to 34,000. For product TM498, the customers earn around 46,000 to 52,000. The product TM798 customers tends to be the one to earn higher income within a range of 56,000 to 90,000.

# %%
sns.catplot(data=df, x="Product", y="Usage", kind="violin");

# %% [markdown]
# The graph above shows a categorical plot graph of Product and Usage. This explicitly explains the relationship where for product TM195 and TM498, the customers have a usage of about 2 to 5. For product TM498, the customers have a usage of about 4 to 7. This tells us more that the users of TM798 tends to have higher usage of the product when compared to others.

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box");

# %% [markdown]
# The graph above shows a categorical plot graph of Product and Miles. This explicitly explains the relationship where for product TM195, miles covered is within the range of 54 to 100. For TM498, the customers have miles coverage of about 55 to 110. TM798 has better coverage of about 110 upward when compared with others.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.catplot(data=df, x="Product", y="Usage", kind="box", hue="Fitness");

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Usage and Fitness. The three respective products include (TM195, TM498, TM798). As observed, Product TM195 and TM498 have their customers using the product mostly within 2 to 5 per week and fitness score of about 2 to 5. For product TM798, it tends to have higher usage than other products from about 4 above weekly and fitness score of 4 and 5 predominantly. This gives a clearer picture of Product TM798 as the product with better usage and fitness.

# %%
sns.catplot(data=df, x="Product", y="Education", kind="box", hue="Usage" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Education and Usage. The three respective products include (TM195, TM498, TM798). While Product TM195 and TM498 have Education class range from 14 to 16 and usage of about 2 to 5. Product TM798 have its Education class range most prevalent around 16to 18 years with the usage of about 4 to 7.

# %%
sns.catplot(data=df, x="Product", y="Education", kind="box", hue="Fitness");

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Education and Fitness. The three respective products include (TM195, TM498, TM798). Under Product TM195 and TM498, the Education of customers ranges from 14 to 16 as well as their fitness score being around 2 to 4. For Product TM798, the Education of customers ranges from 16 to 18 as well as their fitness being around 3 to 5 times per week. A clear picture of TM798 was shown to be the product with the best fitness score.

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box", hue="Usage" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Income and Usage. The three respective products include (TM195, TM498, TM798). Under Product TM195 and TM498, their customers income ranges around 35,000 to 55,000 and their usage being 2 to 5. For Product TM798, their customers earn higher income from 55,000 above with usage of product of 4 above weekly. This tells us that for Product TM798 users earn more. The more they earn, the more their usage as observed.

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box", hue="Fitness" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Income and Fitness. The three respective products include (TM195, TM498, TM798). Under Product TM195 and TM498, their customers income ranges around 35,000 to 55,000 and their fitness score being 2 to 5. For Product TM798, their customers earn higher income from 55,000 above with fitness score of product of 3 to 5 above weekly. This tells us that for Product TM798 users earn more. The more they earn, the more their usage, hence, the increase in their fitness as shown to have a strong correlation.

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box", hue="Gender" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Income and Gender. Both males and females actively use the 3 products in different proportions. Observation shows clearly that TM798 customers earn higher than ohers where the earners are more of females than males.

# %%
sns.lineplot(data=df, x="Product", y="Income", hue="MaritalStatus" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, MaritalStatus and Income. Both Singles and partnered actively use the 3 products in different proportions. Observation shows clearly that TM798 customers that are artnered use the products the more.

# %%
sns.lineplot(data=df, x="Product", y="Education", hue="Gender" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Education and Gender. The three respective products include (TM195, TM498, TM798). Both males and females actively use the 3 products in different proportions. For Product TM195 and TM498, the Education of the products for both Gender falls between 14 and 16. For Product TM798, the Education range is within 16 to 18. We have more of males than females in this category.

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box", hue="Gender" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Miles and Gender. Both males and females actively use the 3 products in different proportions. We have prevalently under TM798 to be the product with most miles covered by customers as female gender having the highest mile covered.

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box", hue="Usage" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Miles and Usage. TM195 and TM498 have lower miles covered and usage when compared with TM798. We have prevalently under TM798 to be the product with most miles covered by customers as well as having the higher usage.

# %%
sns.catplot(data=df, x="Product", y="Age", kind="box", hue="Fitness" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Age and Fitness. Relatively, the age spread for most products lies within 23 to 35.  But TM798 is the product with higher level of fitness around this age range.

# %%
sns.catplot(data=df, x="Product", y="Age", kind="box", hue="Usage" );

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Age and Usage. Relatively, the age spread for most products lies within 23 to 35.  But TM798 is the product with higher level of usage around this age range spanning across 4 to 7.

# %% [markdown]
# # CONCLUSION AND INSIGHTS

# %% [markdown]
# The Dataset explained the Cardio Good Fitness products of its customers. The products are classified into 3 namely "TM195", "TM498" AND "TM798". The Dataset provided us with information concerning the most used product "TM195" where the prevalent age range lies within the younger age. The male gender was observed to be the most prominent user of the product as well. Relatively, we have got more of partnered people using the product.
#
# One key observation about the Dataset is that there seems to be a strong correlation between the income, usage, miles and fitness of the customers. They are positively related and that explains their strong correlation where the higher  the income, which proportonally directs the higher usage of the treadmill trascending into more miles covered. Hence, a better fitness score rating by the customer.
#
# Individually, TM195 was seen to be the product with wide usage. TM498 was observed to be the second product with larger customer usage as well. But, after careful review of the Dataset, it was deduced that TM798 with the lowset customer usage tends to have customers usage of high income earners that use the products very well on an average weekly and have them cove more miles. TM798 uers were observed to be the customers with top rated fitness score. It can be inferred that TM195 and TM498 products are less expensive to use. Thus, attracts lower income earners.
#
# In conclusion, Age was seen as a huge factor as well. The higher the age, the higher the Income of users which affects the usage of the individual products.

# %% [markdown]
# # RECOMENDATION

# %% [markdown]
# A very good strategy to use is for the owners should consider flexible pricing options, discounts, or bundled packages, taking into account the economic range identified in the dataset. This can enhance affordability and accessibility for a wider audience.
# They can also focus Marketing campaigns for TM798. Concentrate marketing efforts on promoting the TM798 product, highlighting its popularity and effectiveness in achieving optimal fitness levels. Emphasize features that appeal to the identified demographic.
# Also, Targeted Campaigns for Demographic to develop targeted marketing campaigns for the 25-30 age group, primarily comprising males with higher incomes. Tailor messages to align with their fitness goals and preferences.
# Implementing a system for continuous monitoring of user preferences, adapting marketing strategies in real-time as trends evolve. Regularly update product features based on user feedback to enhance overall user experience.
